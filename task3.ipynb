# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
# !type C:\Users\Administrator\Desktop\test\task3.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,fool

# %%
df = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
pd.read_table(r'C:\Users\Administrator\Desktop\test\task3.csv',sep=',')
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
data = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv',header=None)
data
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12     fool

# %%
pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv',names=['A','B','C','D','E']).style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow0_col0 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow0_col1 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow0_col2 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow0_col3 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow0_col4 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow1_col0 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow1_col1 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow1_col2 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow1_col3 {
#             text-align:  center;
#         }    #T_5088801e_ba81_11e9_8eb2_28e347f786ebrow1_col4 {
# ...

# %%
pd.options.display.max_rows = 10
result = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv')
result
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv',nrows=5)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
chunker = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv',chunksize=1)
chunker

# %%
chunker = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv',chunksize=1)
tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['message'].value_counts(),fill_value=0)
tot = tot.sort_values(ascending=False)

# %%
tot[:10]
# Out:
# world    1.0
# hello    1.0
# fool     1.0
# dtype: float64

# %%
data.to_csv(r'C:\Users\Administrator\Desktop\test\out.csv')

# %%
# !type C:\Users\Administrator\Desktop\test\out.csv
# Out:
# ,0,1,2,3,4
# 0,a,b,c,d,message
# 1,1,2,3,4,hello
# 2,5,6,7,8,world
# 3,9,10,11,12,fool

# %%
import sys
data.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,0,1,2,3,4
# 0,a,b,c,d,message
# 1,1,2,3,4,hello
# 2,5,6,7,8,world
# 3,9,10,11,12,fool

# %%
data.to_csv(sys.stdout,index=False,header=False)
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,fool

# %%
# !type C:\Users\Administrator\Desktop\test\test.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
import csv
f = open(r'C:\Users\Administrator\Desktop\test\test.csv')
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open(r'C:\Users\Administrator\Desktop\test\test.csv') as f:
    lines = list(csv.reader(f))
header,values = lines[0],lines[1:]
data_dict = {h: v for h,v in zip(header,zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
class my_dialect(csv.Dialect):
    lineterminatore = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL
f = open(r'C:\Users\Administrator\Desktop\test\test.csv',"r")
reader = csv.reader(f,dialect=my_dialect)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-61c7e05e1e1b> in <module>
#       5     quoting = csv.QUOTE_MINIMAL
#       6 f = open(r'C:\Users\Administrator\Desktop\test\test.csv',"r")
# ----> 7 reader = csv.reader(f,dialect=my_dialect)
#
# TypeError: lineterminator must be set

# %%
obj = """
{"name":"Wes",
"places_lived":["United States","Spain","Germany"],
"pet":null,
"siblings":[{"name":"Scott","age":30,"pets":["Zeus","Zuko"]},
	    {"name":"Katie","age":38,
	     "pets":["Sixes","Stache","Cisco"]}]
}"""
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
siblings = pd.DataFrame(result['siblings'],columns=['name','age','pets'])
siblings
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]

# %%
# !type C:\Users\Administrator\Desktop\test\test.json
# Out:
# [{"a":1,"b":2,"c":3},
#  {"a":4,"b":5,"c":6},
#  {"a":7,"b":8,"c":9}]

# %%
data = pd.read_json(r'C:\Users\Administrator\Desktop\test\test.json')

# %%
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %%
print(data.to_json(orient='records'))
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
from lxml import objectify
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()
root
# Out:
# <Element a at 0x1273a388>

# %%
root.get('href')
# Out:
# 'http://www.google.com'

# %%
root.text
# Out:
# 'Google'

# %%
frame = pd.read_csv(r'C:\Users\Administrator\Desktop\test\task3.csv')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
frame.to_pickle(r'C:\Users\Administrator\Desktop\test\task3_pickle')

# %%
pd.read_pickle(r'C:\Users\Administrator\Desktop\test\task3_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
frame = pd.DataFrame({'a':np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# E:\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0   0.190090
# 1  -0.226463
# 2  -1.860949
# 3  -0.782320
# 4  -1.186874
# ..       ...
# 95 -0.912451
# 96 -1.078584
# 97 -0.623030
# 98  0.041783
# 99 -0.062953
#
# [100 rows x 1 columns]

# %%
xlsx = pd.ExcelFile(r'C:\Users\Administrator\Desktop\test\task3.xlsx')

# %%
pd.read_excel(xlsx)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
frame = pd.read_excel(r'C:\Users\Administrator\Desktop\test\task3.xlsx')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    fool

# %%
writer = pd.ExcelWriter(r'C:\Users\Administrator\Desktop\test\test.xlsx')
frame.to_excel(writer)
writer.save()

# %%
frame.to_excel(r'C:\Users\Administrator\Desktop\test\test.xlsx')

# %%
import requests
res = requests.get('https://api.github.com/pandas-dev/pandas/issues')
res.json()
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://developer.github.com/v3'}

# %%
import requests
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '10185944504',
#   'type': 'CreateEvent',
#   'actor': {'id': 6173051,
#    'login': 'jochenvdv',
#    'display_login': 'jochenvdv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jochenvdv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6173051?'},
#   'repo': {'id': 201603540,
#    'name': 'jochenvdv/MobileApps_iOS_Werkstuk_1',
#    'url': 'https://api.github.com/repos/jochenvdv/MobileApps_iOS_Werkstuk_1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-08-10T08:40:24Z'},
#  {'id': '10185944501',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 28721952,
#    'login': 'yunpingdu',
#    'display_login': 'yunpingdu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yunpingdu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28721952?'},
#   'repo': {'id': 198456933,
# ...

# %%
import sqlite3
query = """
CREATE TABLE test
(a VARCHAR(20),b VARCHAR(20),c REAL,d INTEGER);"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data = [('Atlanda','Georgia',1.25,6),
       ('Tallahassee','Florida',2.6,3),
       ('Sacramento','Califonia',1.7,5)]

# %%
stmt = "INSERT INTO test VALUES(?,?,?,?)"
con.executemany(stmt,data)

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanda', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'Califonia', 1.7, 5)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows,columns=[x[0] for x in cursor.description])
# Out:
#              a          b     c  d
# 0      Atlanda    Georgia  1.25  6
# 1  Tallahassee    Florida  2.60  3
# 2   Sacramento  Califonia  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test',db)
# Out:
# Empty DataFrame
# Columns: [a, b, c, d]
# Index: []
